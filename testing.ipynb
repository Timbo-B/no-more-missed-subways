# %% [markdown]
# # sandbox

# %%
from google.transit import gtfs_realtime_pb2
from google.protobuf.json_format import MessageToDict

# %%
import requests
import time
import datetime
import time
from datetime import datetime

# %%
APIKey = ''

# %%
NQRWfeed = 'https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-nqrw' # N,Q,R,W 
BDFMfeed = 'https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-bdfm' # B,D,F,M
S123456feed = 'https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs' # 1,2,3,4,5,6,7
ACEHfeed = 'https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-ace' # A,C,E,H 
Lfeed = 'https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-l' # L 
Gfeed = 'https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-g' # G 
JZfeed = 'https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-jz' # JZ 
SIRfeed = 'https://api-endpoint.mta.info/Dataservice/mtagtfsfeeds/nyct%2Fgtfs-si' # SIR
feeds = [NQRWfeed,BDFMfeed,S123456feed,ACEHfeed,Lfeed,Gfeed,JZfeed,SIRfeed]

# %%
import pandas as pd

# %%
stations = [{'stop_id': '112',
  'name': '168 St-Washington Hts',
  'lat': 40.840556,
  'lon': -73.940133,
  'parent_id': '112'},
 {'stop_id': 'A09',
  'name': '168 St',
  'lat': 40.840719,
  'lon': -73.939561,
  'parent_id': '112'},
 {'stop_id': 'A24',
  'name': '59 St-Columbus Circle',
  'lat': 40.768296,
  'lon': -73.981736,
  'parent_id': '125'},
 {'stop_id': '125',
  'name': '59 St-Columbus Circle',
  'lat': 40.768247,
  'lon': -73.981929,
  'parent_id': '125'},
 {'stop_id': 'A27',
  'name': '42 St-Port Authority Bus Terminal',
  'lat': 40.757308,
  'lon': -73.989735,
  'parent_id': 'A27'},
 {'stop_id': '725',
  'name': 'Times Sq-42 St',
  'lat': 40.755477,
  'lon': -73.987691,
  'parent_id': '127'},
 {'stop_id': '902',
  'name': 'Times Sq-42 St',
  'lat': 40.755983,
  'lon': -73.986229,
  'parent_id': '127'},
 {'stop_id': '127',
  'name': 'Times Sq-42 St',
  'lat': 40.75529,
  'lon': -73.987495,
  'parent_id': '127'},
 {'stop_id': 'R16',
  'name': 'Times Sq-42 St',
  'lat': 40.754672,
  'lon': -73.986754,
  'parent_id': '127'},
 {'stop_id': '132',
  'name': '14 St',
  'lat': 40.737826,
  'lon': -74.000201,
  'parent_id': '132'},
 {'stop_id': 'L02',
  'name': '6 Av',
  'lat': 40.737335,
  'lon': -73.996786,
  'parent_id': 'D19'},
 {'stop_id': 'D19',
  'name': '14 St',
  'lat': 40.738228,
  'lon': -73.996209,
  'parent_id': 'D19'},
 {'stop_id': 'R27',
  'name': 'Whitehall St-South Ferry',
  'lat': 40.703087,
  'lon': -74.012994,
  'parent_id': '140'},
 {'stop_id': '140',
  'name': 'South Ferry Loop',
  'lat': 40.701411,
  'lon': -74.013205,
  'parent_id': '140'},
 {'stop_id': '415',
  'name': '149 St-Grand Concourse',
  'lat': 40.818375,
  'lon': -73.927351,
  'parent_id': '222'},
 {'stop_id': '222',
  'name': '149 St-Grand Concourse',
  'lat': 40.81841,
  'lon': -73.926718,
  'parent_id': '222'},
 {'stop_id': '228',
  'name': 'Park Place',
  'lat': 40.713051,
  'lon': -74.008811,
  'parent_id': '228'},
 {'stop_id': 'E01',
  'name': 'World Trade Center',
  'lat': 40.712582,
  'lon': -74.009781,
  'parent_id': 'E01'},
 {'stop_id': 'A36',
  'name': 'Chambers St',
  'lat': 40.714111,
  'lon': -74.008585,
  'parent_id': 'A36'},
 {'stop_id': 'R25',
  'name': 'Cortlandt St',
  'lat': 40.710668,
  'lon': -74.011029,
  'parent_id': 'R25'},
 {'stop_id': '418',
  'name': 'Fulton St',
  'lat': 40.710368,
  'lon': -74.009509,
  'parent_id': '229'},
 {'stop_id': 'A38',
  'name': 'Fulton St',
  'lat': 40.710197,
  'lon': -74.007691,
  'parent_id': '229'},
 {'stop_id': '229',
  'name': 'Fulton St',
  'lat': 40.709416,
  'lon': -74.006571,
  'parent_id': '229'},
 {'stop_id': 'M22',
  'name': 'Fulton St',
  'lat': 40.710374,
  'lon': -74.007582,
  'parent_id': '229'},
 {'stop_id': '423',
  'name': 'Borough Hall',
  'lat': 40.692404,
  'lon': -73.990151,
  'parent_id': '232'},
 {'stop_id': 'R28',
  'name': 'Court St',
  'lat': 40.6941,
  'lon': -73.991777,
  'parent_id': '232'},
 {'stop_id': '232',
  'name': 'Borough Hall',
  'lat': 40.693219,
  'lon': -73.989998,
  'parent_id': '232'},
 {'stop_id': 'R31',
  'name': 'Atlantic Av-Barclays Ctr',
  'lat': 40.683666,
  'lon': -73.97881,
  'parent_id': '235'},
 {'stop_id': 'D24',
  'name': 'Atlantic Av-Barclays Ctr',
  'lat': 40.68446,
  'lon': -73.97689,
  'parent_id': '235'},
 {'stop_id': '235',
  'name': 'Atlantic Av-Barclays Ctr',
  'lat': 40.684359,
  'lon': -73.977666,
  'parent_id': '235'},
 {'stop_id': '239',
  'name': 'Franklin Av-Medgar Evers College',
  'lat': 40.670682,
  'lon': -73.958131,
  'parent_id': '239'},
 {'stop_id': 'S04',
  'name': 'Botanic Garden',
  'lat': 40.670343,
  'lon': -73.959245,
  'parent_id': '239'},
 {'stop_id': 'L26',
  'name': 'Livonia Av',
  'lat': 40.664038,
  'lon': -73.900571,
  'parent_id': '254'},
 {'stop_id': '254',
  'name': 'Junius St',
  'lat': 40.663515,
  'lon': -73.902447,
  'parent_id': '254'},
 {'stop_id': 'D11',
  'name': '161 St-Yankee Stadium',
  'lat': 40.827905,
  'lon': -73.925651,
  'parent_id': '414'},
 {'stop_id': '414',
  'name': '161 St-Yankee Stadium',
  'lat': 40.827994,
  'lon': -73.925831,
  'parent_id': '414'},
 {'stop_id': 'R11',
  'name': 'Lexington Av/59 St',
  'lat': 40.76266,
  'lon': -73.967258,
  'parent_id': '629'},
 {'stop_id': 'B08',
  'name': 'Lexington Av/63 St',
  'lat': 40.764629,
  'lon': -73.966113,
  'parent_id': 'B08'},
 {'stop_id': '629',
  'name': '59 St',
  'lat': 40.762526,
  'lon': -73.967967,
  'parent_id': '629'},
 {'stop_id': '630',
  'name': '51 St',
  'lat': 40.757107,
  'lon': -73.97192,
  'parent_id': '630'},
 {'stop_id': 'F11',
  'name': 'Lexington Av/53 St',
  'lat': 40.757552,
  'lon': -73.969055,
  'parent_id': '630'},
 {'stop_id': '723',
  'name': 'Grand Central-42 St',
  'lat': 40.751431,
  'lon': -73.976041,
  'parent_id': '631'},
 {'stop_id': '631',
  'name': 'Grand Central-42 St',
  'lat': 40.751776,
  'lon': -73.976848,
  'parent_id': '631'},
 {'stop_id': '901',
  'name': 'Grand Central-42 St',
  'lat': 40.752769,
  'lon': -73.979189,
  'parent_id': '631'},
 {'stop_id': 'L03',
  'name': '14 St-Union Sq',
  'lat': 40.734789,
  'lon': -73.99073,
  'parent_id': '635'},
 {'stop_id': '635',
  'name': '14 St-Union Sq',
  'lat': 40.734673,
  'lon': -73.989951,
  'parent_id': '635'},
 {'stop_id': 'R20',
  'name': '14 St-Union Sq',
  'lat': 40.735736,
  'lon': -73.990568,
  'parent_id': '635'},
 {'stop_id': '637',
  'name': 'Bleecker St',
  'lat': 40.725915,
  'lon': -73.994659,
  'parent_id': '637'},
 {'stop_id': 'D21',
  'name': 'Broadway-Lafayette St',
  'lat': 40.725297,
  'lon': -73.996204,
  'parent_id': '637'},
 {'stop_id': 'Q01',
  'name': 'Canal St',
  'lat': 40.718383,
  'lon': -74.00046,
  'parent_id': '639'},
 {'stop_id': '639',
  'name': 'Canal St',
  'lat': 40.718803,
  'lon': -74.000193,
  'parent_id': '639'},
 {'stop_id': 'R23',
  'name': 'Canal St',
  'lat': 40.719527,
  'lon': -74.001775,
  'parent_id': '639'},
 {'stop_id': 'M20',
  'name': 'Canal St',
  'lat': 40.718092,
  'lon': -73.999892,
  'parent_id': '639'},
 {'stop_id': 'M21',
  'name': 'Chambers St',
  'lat': 40.713243,
  'lon': -74.003401,
  'parent_id': '640'},
 {'stop_id': '640',
  'name': 'Brooklyn Bridge-City Hall',
  'lat': 40.713065,
  'lon': -74.004131,
  'parent_id': '640'},
 {'stop_id': 'G14',
  'name': 'Jackson Hts-Roosevelt Av',
  'lat': 40.746644,
  'lon': -73.891338,
  'parent_id': '710'},
 {'stop_id': '710',
  'name': '74 St-Broadway',
  'lat': 40.746848,
  'lon': -73.891394,
  'parent_id': '710'},
 {'stop_id': '718',
  'name': 'Queensboro Plaza',
  'lat': 40.750582,
  'lon': -73.940202,
  'parent_id': '718'},
 {'stop_id': 'R09',
  'name': 'Queensboro Plaza',
  'lat': 40.750582,
  'lon': -73.940202,
  'parent_id': '718'},
 {'stop_id': 'F09',
  'name': 'Court Sq-23 St',
  'lat': 40.747846,
  'lon': -73.946,
  'parent_id': '719'},
 {'stop_id': '719',
  'name': 'Court Sq',
  'lat': 40.747023,
  'lon': -73.945264,
  'parent_id': '719'},
 {'stop_id': 'G22',
  'name': 'Court Sq',
  'lat': 40.746554,
  'lon': -73.943832,
  'parent_id': '719'},
 {'stop_id': 'D16',
  'name': '42 St-Bryant Pk',
  'lat': 40.754222,
  'lon': -73.984569,
  'parent_id': 'D16'},
 {'stop_id': '724',
  'name': '5 Av',
  'lat': 40.753821,
  'lon': -73.981963,
  'parent_id': '724'},
 {'stop_id': 'A12',
  'name': '145 St',
  'lat': 40.824783,
  'lon': -73.944216,
  'parent_id': 'A12'},
 {'stop_id': 'D13',
  'name': '145 St',
  'lat': 40.824783,
  'lon': -73.944216,
  'parent_id': 'A12'},
 {'stop_id': 'L01',
  'name': '8 Av',
  'lat': 40.739777,
  'lon': -74.002578,
  'parent_id': 'A31'},
 {'stop_id': 'A31',
  'name': '14 St',
  'lat': 40.740893,
  'lon': -74.00169,
  'parent_id': 'A31'},
 {'stop_id': 'D20',
  'name': 'W 4 St-Wash Sq',
  'lat': 40.732338,
  'lon': -74.000495,
  'parent_id': 'A32'},
 {'stop_id': 'A32',
  'name': 'W 4 St-Wash Sq',
  'lat': 40.732338,
  'lon': -74.000495,
  'parent_id': 'A32'},
 {'stop_id': 'A41',
  'name': 'Jay St-MetroTech',
  'lat': 40.692338,
  'lon': -73.987342,
  'parent_id': 'A41'},
 {'stop_id': 'R29',
  'name': 'Jay St-MetroTech',
  'lat': 40.69218,
  'lon': -73.985942,
  'parent_id': 'A41'},
 {'stop_id': 'S01',
  'name': 'Franklin Av',
  'lat': 40.680596,
  'lon': -73.955827,
  'parent_id': 'A45'},
 {'stop_id': 'A45',
  'name': 'Franklin Av',
  'lat': 40.68138,
  'lon': -73.956848,
  'parent_id': 'A45'},
 {'stop_id': 'J27',
  'name': 'Broadway Junction',
  'lat': 40.679498,
  'lon': -73.904512,
  'parent_id': 'A51'},
 {'stop_id': 'A51',
  'name': 'Broadway Junction',
  'lat': 40.678334,
  'lon': -73.905316,
  'parent_id': 'A51'},
 {'stop_id': 'L22',
  'name': 'Broadway Junction',
  'lat': 40.678856,
  'lon': -73.90324,
  'parent_id': 'A51'},
 {'stop_id': 'N04',
  'name': 'New Utrecht Av',
  'lat': 40.624842,
  'lon': -73.996353,
  'parent_id': 'B16'},
 {'stop_id': 'B16',
  'name': '62 St',
  'lat': 40.626472,
  'lon': -73.996895,
  'parent_id': 'B16'},
 {'stop_id': 'D17',
  'name': '34 St-Herald Sq',
  'lat': 40.749719,
  'lon': -73.987823,
  'parent_id': 'D17'},
 {'stop_id': 'R17',
  'name': '34 St-Herald Sq',
  'lat': 40.749567,
  'lon': -73.98795,
  'parent_id': 'D17'},
 {'stop_id': 'F15',
  'name': 'Delancey St-Essex St',
  'lat': 40.718611,
  'lon': -73.988114,
  'parent_id': 'F15'},
 {'stop_id': 'M18',
  'name': 'Delancey St-Essex St',
  'lat': 40.718315,
  'lon': -73.987437,
  'parent_id': 'F15'},
 {'stop_id': 'R33',
  'name': '4 Av-9 St',
  'lat': 40.670847,
  'lon': -73.988302,
  'parent_id': 'F23'},
 {'stop_id': 'F23',
  'name': '4 Av-9 St',
  'lat': 40.670272,
  'lon': -73.989779,
  'parent_id': 'F23'},
 {'stop_id': 'L10',
  'name': 'Lorimer St',
  'lat': 40.714063,
  'lon': -73.950275,
  'parent_id': 'G29'},
 {'stop_id': 'G29',
  'name': 'Metropolitan Av',
  'lat': 40.712792,
  'lon': -73.951418,
  'parent_id': 'G29'},
 {'stop_id': 'M08',
  'name': 'Myrtle-Wyckoff Avs',
  'lat': 40.69943,
  'lon': -73.912385,
  'parent_id': 'L17'},
 {'stop_id': 'L17',
  'name': 'Myrtle-Wyckoff Avs',
  'lat': 40.699814,
  'lon': -73.911586,
  'parent_id': 'L17'},
 {'stop_id': '101',
  'name': 'Van Cortlandt Park-242 St',
  'lat': 40.889248,
  'lon': -73.898583,
  'parent_id': '101'},
 {'stop_id': '103',
  'name': '238 St',
  'lat': 40.884667,
  'lon': -73.90087,
  'parent_id': '103'},
 {'stop_id': '104',
  'name': '231 St',
  'lat': 40.878856,
  'lon': -73.904834,
  'parent_id': '104'},
 {'stop_id': '106',
  'name': 'Marble Hill-225 St',
  'lat': 40.874561,
  'lon': -73.909831,
  'parent_id': '106'},
 {'stop_id': '107',
  'name': '215 St',
  'lat': 40.869444,
  'lon': -73.915279,
  'parent_id': '107'},
 {'stop_id': '108',
  'name': '207 St',
  'lat': 40.864621,
  'lon': -73.918822,
  'parent_id': '108'},
 {'stop_id': '109',
  'name': 'Dyckman St',
  'lat': 40.860531,
  'lon': -73.925536,
  'parent_id': '109'},
 {'stop_id': '110',
  'name': '191 St',
  'lat': 40.855225,
  'lon': -73.929412,
  'parent_id': '110'},
 {'stop_id': '111',
  'name': '181 St',
  'lat': 40.849505,
  'lon': -73.933596,
  'parent_id': '111'},
 {'stop_id': '113',
  'name': '157 St',
  'lat': 40.834041,
  'lon': -73.94489,
  'parent_id': '113'},
 {'stop_id': '114',
  'name': '145 St',
  'lat': 40.826551,
  'lon': -73.95036,
  'parent_id': '114'},
 {'stop_id': '115',
  'name': '137 St-City College',
  'lat': 40.822008,
  'lon': -73.953676,
  'parent_id': '115'},
 {'stop_id': '116',
  'name': '125 St',
  'lat': 40.815581,
  'lon': -73.958372,
  'parent_id': '116'},
 {'stop_id': '117',
  'name': '116 St-Columbia University',
  'lat': 40.807722,
  'lon': -73.96411,
  'parent_id': '117'},
 {'stop_id': '118',
  'name': 'Cathedral Pkwy (110 St)',
  'lat': 40.803967,
  'lon': -73.966847,
  'parent_id': '118'},
 {'stop_id': '119',
  'name': '103 St',
  'lat': 40.799446,
  'lon': -73.968379,
  'parent_id': '119'},
 {'stop_id': '120',
  'name': '96 St',
  'lat': 40.793919,
  'lon': -73.972323,
  'parent_id': '120'},
 {'stop_id': '121',
  'name': '86 St',
  'lat': 40.788644,
  'lon': -73.976218,
  'parent_id': '121'},
 {'stop_id': '122',
  'name': '79 St',
  'lat': 40.783934,
  'lon': -73.979917,
  'parent_id': '122'},
 {'stop_id': '123',
  'name': '72 St',
  'lat': 40.778453,
  'lon': -73.98197,
  'parent_id': '123'},
 {'stop_id': '124',
  'name': '66 St-Lincoln Center',
  'lat': 40.77344,
  'lon': -73.982209,
  'parent_id': '124'},
 {'stop_id': '126',
  'name': '50 St',
  'lat': 40.761728,
  'lon': -73.983849,
  'parent_id': '126'},
 {'stop_id': '128',
  'name': '34 St-Penn Station',
  'lat': 40.750373,
  'lon': -73.991057,
  'parent_id': '128'},
 {'stop_id': '129',
  'name': '28 St',
  'lat': 40.747215,
  'lon': -73.993365,
  'parent_id': '129'},
 {'stop_id': '130',
  'name': '23 St',
  'lat': 40.744081,
  'lon': -73.995657,
  'parent_id': '130'},
 {'stop_id': '131',
  'name': '18 St',
  'lat': 40.74104,
  'lon': -73.997871,
  'parent_id': '131'},
 {'stop_id': '133',
  'name': 'Christopher St-Sheridan Sq',
  'lat': 40.733422,
  'lon': -74.002906,
  'parent_id': '133'},
 {'stop_id': '134',
  'name': 'Houston St',
  'lat': 40.728251,
  'lon': -74.005367,
  'parent_id': '134'},
 {'stop_id': '135',
  'name': 'Canal St',
  'lat': 40.722854,
  'lon': -74.006277,
  'parent_id': '135'},
 {'stop_id': '136',
  'name': 'Franklin St',
  'lat': 40.719318,
  'lon': -74.006886,
  'parent_id': '136'},
 {'stop_id': '137',
  'name': 'Chambers St',
  'lat': 40.715478,
  'lon': -74.009266,
  'parent_id': '137'},
 {'stop_id': '138',
  'name': 'WTC Cortlandt',
  'lat': 40.711835,
  'lon': -74.012188,
  'parent_id': '138'},
 {'stop_id': '139',
  'name': 'Rector St',
  'lat': 40.707513,
  'lon': -74.013783,
  'parent_id': '139'},
 {'stop_id': '142',
  'name': 'South Ferry',
  'lat': 40.702068,
  'lon': -74.013664,
  'parent_id': '142'},
 {'stop_id': '201',
  'name': 'Wakefield-241 St',
  'lat': 40.903125,
  'lon': -73.85062,
  'parent_id': '201'},
 {'stop_id': '204',
  'name': 'Nereid Av',
  'lat': 40.898379,
  'lon': -73.854376,
  'parent_id': '204'},
 {'stop_id': '205',
  'name': '233 St',
  'lat': 40.893193,
  'lon': -73.857473,
  'parent_id': '205'},
 {'stop_id': '206',
  'name': '225 St',
  'lat': 40.888022,
  'lon': -73.860341,
  'parent_id': '206'},
 {'stop_id': '207',
  'name': '219 St',
  'lat': 40.883895,
  'lon': -73.862633,
  'parent_id': '207'},
 {'stop_id': '208',
  'name': 'Gun Hill Rd',
  'lat': 40.87785,
  'lon': -73.866256,
  'parent_id': '208'},
 {'stop_id': '209',
  'name': 'Burke Av',
  'lat': 40.871356,
  'lon': -73.867164,
  'parent_id': '209'},
 {'stop_id': '210',
  'name': 'Allerton Av',
  'lat': 40.865462,
  'lon': -73.867352,
  'parent_id': '210'},
 {'stop_id': '211',
  'name': 'Pelham Pkwy',
  'lat': 40.857192,
  'lon': -73.867615,
  'parent_id': '211'},
 {'stop_id': '212',
  'name': 'Bronx Park East',
  'lat': 40.848828,
  'lon': -73.868457,
  'parent_id': '212'},
 {'stop_id': '213',
  'name': 'E 180 St',
  'lat': 40.841894,
  'lon': -73.873488,
  'parent_id': '213'},
 {'stop_id': '214',
  'name': 'West Farms Sq-E Tremont Av',
  'lat': 40.840295,
  'lon': -73.880049,
  'parent_id': '214'},
 {'stop_id': '215',
  'name': '174 St',
  'lat': 40.837288,
  'lon': -73.887734,
  'parent_id': '215'},
 {'stop_id': '216',
  'name': 'Freeman St',
  'lat': 40.829993,
  'lon': -73.891865,
  'parent_id': '216'},
 {'stop_id': '217',
  'name': 'Simpson St',
  'lat': 40.824073,
  'lon': -73.893064,
  'parent_id': '217'},
 {'stop_id': '218',
  'name': 'Intervale Av',
  'lat': 40.822181,
  'lon': -73.896736,
  'parent_id': '218'},
 {'stop_id': '219',
  'name': 'Prospect Av',
  'lat': 40.819585,
  'lon': -73.90177,
  'parent_id': '219'},
 {'stop_id': '220',
  'name': 'Jackson Av',
  'lat': 40.81649,
  'lon': -73.907807,
  'parent_id': '220'},
 {'stop_id': '221',
  'name': '3 Av-149 St',
  'lat': 40.816109,
  'lon': -73.917757,
  'parent_id': '221'},
 {'stop_id': '224',
  'name': '135 St',
  'lat': 40.814229,
  'lon': -73.94077,
  'parent_id': '224'},
 {'stop_id': '225',
  'name': '125 St',
  'lat': 40.807754,
  'lon': -73.945495,
  'parent_id': '225'},
 {'stop_id': '226',
  'name': '116 St',
  'lat': 40.802098,
  'lon': -73.949625,
  'parent_id': '226'},
 {'stop_id': '227',
  'name': 'Central Park North (110 St)',
  'lat': 40.799075,
  'lon': -73.951822,
  'parent_id': '227'},
 {'stop_id': '230',
  'name': 'Wall St',
  'lat': 40.706821,
  'lon': -74.0091,
  'parent_id': '230'},
 {'stop_id': '231',
  'name': 'Clark St',
  'lat': 40.697466,
  'lon': -73.993086,
  'parent_id': '231'},
 {'stop_id': '233',
  'name': 'Hoyt St',
  'lat': 40.690545,
  'lon': -73.985065,
  'parent_id': '233'},
 {'stop_id': '234',
  'name': 'Nevins St',
  'lat': 40.688246,
  'lon': -73.980492,
  'parent_id': '234'},
 {'stop_id': '236',
  'name': 'Bergen St',
  'lat': 40.680829,
  'lon': -73.975098,
  'parent_id': '236'},
 {'stop_id': '237',
  'name': 'Grand Army Plaza',
  'lat': 40.675235,
  'lon': -73.971046,
  'parent_id': '237'},
 {'stop_id': '238',
  'name': 'Eastern Pkwy-Brooklyn Museum',
  'lat': 40.671987,
  'lon': -73.964375,
  'parent_id': '238'},
 {'stop_id': '241',
  'name': 'President St-Medgar Evers College',
  'lat': 40.667883,
  'lon': -73.950683,
  'parent_id': '241'},
 {'stop_id': '242',
  'name': 'Sterling St',
  'lat': 40.662742,
  'lon': -73.95085,
  'parent_id': '242'},
 {'stop_id': '243',
  'name': 'Winthrop St',
  'lat': 40.656652,
  'lon': -73.9502,
  'parent_id': '243'},
 {'stop_id': '244',
  'name': 'Church Av',
  'lat': 40.650843,
  'lon': -73.949575,
  'parent_id': '244'},
 {'stop_id': '245',
  'name': 'Beverly Rd',
  'lat': 40.645098,
  'lon': -73.948959,
  'parent_id': '245'},
 {'stop_id': '246',
  'name': 'Newkirk Av-Little Haiti',
  'lat': 40.639967,
  'lon': -73.948411,
  'parent_id': '246'},
 {'stop_id': '247',
  'name': 'Flatbush Av-Brooklyn College',
  'lat': 40.632836,
  'lon': -73.947642,
  'parent_id': '247'},
 {'stop_id': '248',
  'name': 'Nostrand Av',
  'lat': 40.669847,
  'lon': -73.950466,
  'parent_id': '248'},
 {'stop_id': '249',
  'name': 'Kingston Av',
  'lat': 40.669399,
  'lon': -73.942161,
  'parent_id': '249'},
 {'stop_id': '250',
  'name': 'Crown Hts-Utica Av',
  'lat': 40.668897,
  'lon': -73.932942,
  'parent_id': '250'},
 {'stop_id': '251',
  'name': 'Sutter Av-Rutland Rd',
  'lat': 40.664717,
  'lon': -73.92261,
  'parent_id': '251'},
 {'stop_id': '252',
  'name': 'Saratoga Av',
  'lat': 40.661453,
  'lon': -73.916327,
  'parent_id': '252'},
 {'stop_id': '253',
  'name': 'Rockaway Av',
  'lat': 40.662549,
  'lon': -73.908946,
  'parent_id': '253'},
 {'stop_id': '255',
  'name': 'Pennsylvania Av',
  'lat': 40.664635,
  'lon': -73.894895,
  'parent_id': '255'},
 {'stop_id': '256',
  'name': 'Van Siclen Av',
  'lat': 40.665449,
  'lon': -73.889395,
  'parent_id': '256'},
 {'stop_id': '257',
  'name': 'New Lots Av',
  'lat': 40.666235,
  'lon': -73.884079,
  'parent_id': '257'},
 {'stop_id': '301',
  'name': 'Harlem-148 St',
  'lat': 40.82388,
  'lon': -73.93647,
  'parent_id': '301'},
 {'stop_id': '302',
  'name': '145 St',
  'lat': 40.820421,
  'lon': -73.936245,
  'parent_id': '302'},
 {'stop_id': '401',
  'name': 'Woodlawn',
  'lat': 40.886037,
  'lon': -73.878751,
  'parent_id': '401'},
 {'stop_id': '402',
  'name': 'Mosholu Pkwy',
  'lat': 40.87975,
  'lon': -73.884655,
  'parent_id': '402'},
 {'stop_id': '405',
  'name': 'Bedford Park Blvd-Lehman College',
  'lat': 40.873412,
  'lon': -73.890064,
  'parent_id': '405'},
 {'stop_id': '406',
  'name': 'Kingsbridge Rd',
  'lat': 40.86776,
  'lon': -73.897174,
  'parent_id': '406'},
 {'stop_id': '407',
  'name': 'Fordham Rd',
  'lat': 40.862803,
  'lon': -73.901034,
  'parent_id': '407'},
 {'stop_id': '408',
  'name': '183 St',
  'lat': 40.858407,
  'lon': -73.903879,
  'parent_id': '408'},
 {'stop_id': '409',
  'name': 'Burnside Av',
  'lat': 40.853453,
  'lon': -73.907684,
  'parent_id': '409'},
 {'stop_id': '410',
  'name': '176 St',
  'lat': 40.84848,
  'lon': -73.911794,
  'parent_id': '410'},
 {'stop_id': '411',
  'name': 'Mt Eden Av',
  'lat': 40.844434,
  'lon': -73.914685,
  'parent_id': '411'},
 {'stop_id': '412',
  'name': '170 St',
  'lat': 40.840075,
  'lon': -73.917791,
  'parent_id': '412'},
 {'stop_id': '413',
  'name': '167 St',
  'lat': 40.835537,
  'lon': -73.9214,
  'parent_id': '413'},
 {'stop_id': '416',
  'name': '138 St-Grand Concourse',
  'lat': 40.813224,
  'lon': -73.929849,
  'parent_id': '416'},
 {'stop_id': '419',
  'name': 'Wall St',
  'lat': 40.707557,
  'lon': -74.011862,
  'parent_id': '419'},
 {'stop_id': '420',
  'name': 'Bowling Green',
  'lat': 40.704817,
  'lon': -74.014065,
  'parent_id': '420'},
 {'stop_id': '501',
  'name': 'Eastchester-Dyre Av',
  'lat': 40.8883,
  'lon': -73.830834,
  'parent_id': '501'},
 {'stop_id': '502',
  'name': 'Baychester Av',
  'lat': 40.878663,
  'lon': -73.838591,
  'parent_id': '502'},
 {'stop_id': '503',
  'name': 'Gun Hill Rd',
  'lat': 40.869526,
  'lon': -73.846384,
  'parent_id': '503'},
 {'stop_id': '504',
  'name': 'Pelham Pkwy',
  'lat': 40.858985,
  'lon': -73.855359,
  'parent_id': '504'},
 {'stop_id': '505',
  'name': 'Morris Park',
  'lat': 40.854364,
  'lon': -73.860495,
  'parent_id': '505'},
 {'stop_id': '601',
  'name': 'Pelham Bay Park',
  'lat': 40.852462,
  'lon': -73.828121,
  'parent_id': '601'},
 {'stop_id': '602',
  'name': 'Buhre Av',
  'lat': 40.84681,
  'lon': -73.832569,
  'parent_id': '602'},
 {'stop_id': '603',
  'name': 'Middletown Rd',
  'lat': 40.843863,
  'lon': -73.836322,
  'parent_id': '603'},
 {'stop_id': '604',
  'name': 'Westchester Sq-E Tremont Av',
  'lat': 40.839892,
  'lon': -73.842952,
  'parent_id': '604'},
 {'stop_id': '606',
  'name': 'Zerega Av',
  'lat': 40.836488,
  'lon': -73.847036,
  'parent_id': '606'},
 {'stop_id': '607',
  'name': 'Castle Hill Av',
  'lat': 40.834255,
  'lon': -73.851222,
  'parent_id': '607'},
 {'stop_id': '608',
  'name': 'Parkchester',
  'lat': 40.833226,
  'lon': -73.860816,
  'parent_id': '608'},
 {'stop_id': '609',
  'name': 'St Lawrence Av',
  'lat': 40.831509,
  'lon': -73.867618,
  'parent_id': '609'},
 {'stop_id': '610',
  'name': 'Morrison Av-Soundview',
  'lat': 40.829521,
  'lon': -73.874516,
  'parent_id': '610'},
 {'stop_id': '611',
  'name': 'Elder Av',
  'lat': 40.828584,
  'lon': -73.879159,
  'parent_id': '611'},
 {'stop_id': '612',
  'name': 'Whitlock Av',
  'lat': 40.826525,
  'lon': -73.886283,
  'parent_id': '612'},
 {'stop_id': '613',
  'name': 'Hunts Point Av',
  'lat': 40.820948,
  'lon': -73.890549,
  'parent_id': '613'},
 {'stop_id': '614',
  'name': 'Longwood Av',
  'lat': 40.816104,
  'lon': -73.896435,
  'parent_id': '614'},
 {'stop_id': '615',
  'name': 'E 149 St',
  'lat': 40.812118,
  'lon': -73.904098,
  'parent_id': '615'},
 {'stop_id': '616',
  'name': "E 143 St-St Mary's St",
  'lat': 40.808719,
  'lon': -73.907657,
  'parent_id': '616'},
 {'stop_id': '617',
  'name': 'Cypress Av',
  'lat': 40.805368,
  'lon': -73.914042,
  'parent_id': '617'},
 {'stop_id': '618',
  'name': 'Brook Av',
  'lat': 40.807566,
  'lon': -73.91924,
  'parent_id': '618'},
 {'stop_id': '619',
  'name': '3 Av-138 St',
  'lat': 40.810476,
  'lon': -73.926138,
  'parent_id': '619'},
 {'stop_id': '621',
  'name': '125 St',
  'lat': 40.804138,
  'lon': -73.937594,
  'parent_id': '621'},
 {'stop_id': '622',
  'name': '116 St',
  'lat': 40.798629,
  'lon': -73.941617,
  'parent_id': '622'},
 {'stop_id': '623',
  'name': '110 St',
  'lat': 40.79502,
  'lon': -73.94425,
  'parent_id': '623'},
 {'stop_id': '624',
  'name': '103 St',
  'lat': 40.7906,
  'lon': -73.947478,
  'parent_id': '624'},
 {'stop_id': '625',
  'name': '96 St',
  'lat': 40.785672,
  'lon': -73.95107,
  'parent_id': '625'},
 {'stop_id': '626',
  'name': '86 St',
  'lat': 40.779492,
  'lon': -73.955589,
  'parent_id': '626'},
 {'stop_id': '627',
  'name': '77 St',
  'lat': 40.77362,
  'lon': -73.959874,
  'parent_id': '627'},
 {'stop_id': '628',
  'name': '68 St-Hunter College',
  'lat': 40.768141,
  'lon': -73.96387,
  'parent_id': '628'},
 {'stop_id': '632',
  'name': '33 St',
  'lat': 40.746081,
  'lon': -73.982076,
  'parent_id': '632'},
 {'stop_id': '633',
  'name': '28 St',
  'lat': 40.74307,
  'lon': -73.984264,
  'parent_id': '633'},
 {'stop_id': '634',
  'name': '23 St',
  'lat': 40.739864,
  'lon': -73.986599,
  'parent_id': '634'},
 {'stop_id': '636',
  'name': 'Astor Pl',
  'lat': 40.730054,
  'lon': -73.99107,
  'parent_id': '636'},
 {'stop_id': '638',
  'name': 'Spring St',
  'lat': 40.722301,
  'lon': -73.997141,
  'parent_id': '638'},
 {'stop_id': '701',
  'name': 'Flushing-Main St',
  'lat': 40.7596,
  'lon': -73.83003,
  'parent_id': '701'},
 {'stop_id': '702',
  'name': 'Mets-Willets Point',
  'lat': 40.754622,
  'lon': -73.845625,
  'parent_id': '702'},
 {'stop_id': '705',
  'name': '111 St',
  'lat': 40.75173,
  'lon': -73.855334,
  'parent_id': '705'},
 {'stop_id': '706',
  'name': '103 St-Corona Plaza',
  'lat': 40.749865,
  'lon': -73.8627,
  'parent_id': '706'},
 {'stop_id': '707',
  'name': 'Junction Blvd',
  'lat': 40.749145,
  'lon': -73.869527,
  'parent_id': '707'},
 {'stop_id': '708',
  'name': '90 St-Elmhurst Av',
  'lat': 40.748408,
  'lon': -73.876613,
  'parent_id': '708'},
 {'stop_id': '709',
  'name': '82 St-Jackson Hts',
  'lat': 40.747659,
  'lon': -73.883697,
  'parent_id': '709'},
 {'stop_id': '711',
  'name': '69 St',
  'lat': 40.746325,
  'lon': -73.896403,
  'parent_id': '711'},
 {'stop_id': '712',
  'name': '61 St-Woodside',
  'lat': 40.74563,
  'lon': -73.902984,
  'parent_id': '712'},
 {'stop_id': '713',
  'name': '52 St',
  'lat': 40.744149,
  'lon': -73.912549,
  'parent_id': '713'},
 {'stop_id': '714',
  'name': '46 St-Bliss St',
  'lat': 40.743132,
  'lon': -73.918435,
  'parent_id': '714'},
 {'stop_id': '715',
  'name': '40 St-Lowery St',
  'lat': 40.743781,
  'lon': -73.924016,
  'parent_id': '715'},
 {'stop_id': '716',
  'name': '33 St-Rawson St',
  'lat': 40.744587,
  'lon': -73.930997,
  'parent_id': '716'},
 {'stop_id': '720',
  'name': 'Hunters Point Av',
  'lat': 40.742216,
  'lon': -73.948916,
  'parent_id': '720'},
 {'stop_id': '721',
  'name': 'Vernon Blvd-Jackson Av',
  'lat': 40.742626,
  'lon': -73.953581,
  'parent_id': '721'},
 {'stop_id': '726',
  'name': '34 St-Hudson Yards',
  'lat': 40.755882,
  'lon': -74.00191,
  'parent_id': '726'},
 {'stop_id': 'A02',
  'name': 'Inwood-207 St',
  'lat': 40.868072,
  'lon': -73.919899,
  'parent_id': 'A02'},
 {'stop_id': 'A03',
  'name': 'Dyckman St',
  'lat': 40.865491,
  'lon': -73.927271,
  'parent_id': 'A03'},
 {'stop_id': 'A05',
  'name': '190 St',
  'lat': 40.859022,
  'lon': -73.93418,
  'parent_id': 'A05'},
 {'stop_id': 'A06',
  'name': '181 St',
  'lat': 40.851695,
  'lon': -73.937969,
  'parent_id': 'A06'},
 {'stop_id': 'A07',
  'name': '175 St',
  'lat': 40.847391,
  'lon': -73.939704,
  'parent_id': 'A07'},
 {'stop_id': 'A10',
  'name': '163 St-Amsterdam Av',
  'lat': 40.836013,
  'lon': -73.939892,
  'parent_id': 'A10'},
 {'stop_id': 'A11',
  'name': '155 St',
  'lat': 40.830518,
  'lon': -73.941514,
  'parent_id': 'A11'},
 {'stop_id': 'A14',
  'name': '135 St',
  'lat': 40.817894,
  'lon': -73.947649,
  'parent_id': 'A14'},
 {'stop_id': 'A15',
  'name': '125 St',
  'lat': 40.811109,
  'lon': -73.952343,
  'parent_id': 'A15'},
 {'stop_id': 'A16',
  'name': '116 St',
  'lat': 40.805085,
  'lon': -73.954882,
  'parent_id': 'A16'},
 {'stop_id': 'A17',
  'name': 'Cathedral Pkwy (110 St)',
  'lat': 40.800603,
  'lon': -73.958161,
  'parent_id': 'A17'},
 {'stop_id': 'A18',
  'name': '103 St',
  'lat': 40.796092,
  'lon': -73.961454,
  'parent_id': 'A18'},
 {'stop_id': 'A19',
  'name': '96 St',
  'lat': 40.791642,
  'lon': -73.964696,
  'parent_id': 'A19'},
 {'stop_id': 'A20',
  'name': '86 St',
  'lat': 40.785868,
  'lon': -73.968916,
  'parent_id': 'A20'},
 {'stop_id': 'A21',
  'name': '81 St-Museum of Natural History',
  'lat': 40.781433,
  'lon': -73.972143,
  'parent_id': 'A21'},
 {'stop_id': 'A22',
  'name': '72 St',
  'lat': 40.775594,
  'lon': -73.97641,
  'parent_id': 'A22'},
 {'stop_id': 'A25',
  'name': '50 St',
  'lat': 40.762456,
  'lon': -73.985984,
  'parent_id': 'A25'},
 {'stop_id': 'A28',
  'name': '34 St-Penn Station',
  'lat': 40.752287,
  'lon': -73.993391,
  'parent_id': 'A28'},
 {'stop_id': 'A30',
  'name': '23 St',
  'lat': 40.745906,
  'lon': -73.998041,
  'parent_id': 'A30'},
 {'stop_id': 'A33',
  'name': 'Spring St',
  'lat': 40.726227,
  'lon': -74.003739,
  'parent_id': 'A33'},
 {'stop_id': 'A34',
  'name': 'Canal St',
  'lat': 40.720824,
  'lon': -74.005229,
  'parent_id': 'A34'},
 {'stop_id': 'A40',
  'name': 'High St',
  'lat': 40.699337,
  'lon': -73.990531,
  'parent_id': 'A40'},
 {'stop_id': 'A42',
  'name': 'Hoyt-Schermerhorn Sts',
  'lat': 40.688484,
  'lon': -73.985001,
  'parent_id': 'A42'},
 {'stop_id': 'A43',
  'name': 'Lafayette Av',
  'lat': 40.686113,
  'lon': -73.973946,
  'parent_id': 'A43'},
 {'stop_id': 'A44',
  'name': 'Clinton-Washington Avs',
  'lat': 40.683263,
  'lon': -73.965838,
  'parent_id': 'A44'},
 {'stop_id': 'A46',
  'name': 'Nostrand Av',
  'lat': 40.680438,
  'lon': -73.950426,
  'parent_id': 'A46'},
 {'stop_id': 'A47',
  'name': 'Kingston-Throop Avs',
  'lat': 40.679921,
  'lon': -73.940858,
  'parent_id': 'A47'},
 {'stop_id': 'A48',
  'name': 'Utica Av',
  'lat': 40.679364,
  'lon': -73.930729,
  'parent_id': 'A48'},
 {'stop_id': 'A49',
  'name': 'Ralph Av',
  'lat': 40.678822,
  'lon': -73.920786,
  'parent_id': 'A49'},
 {'stop_id': 'A50',
  'name': 'Rockaway Av',
  'lat': 40.67834,
  'lon': -73.911946,
  'parent_id': 'A50'},
 {'stop_id': 'A52',
  'name': 'Liberty Av',
  'lat': 40.674542,
  'lon': -73.896548,
  'parent_id': 'A52'},
 {'stop_id': 'A53',
  'name': 'Van Siclen Av',
  'lat': 40.67271,
  'lon': -73.890358,
  'parent_id': 'A53'},
 {'stop_id': 'A54',
  'name': 'Shepherd Av',
  'lat': 40.67413,
  'lon': -73.88075,
  'parent_id': 'A54'},
 {'stop_id': 'A55',
  'name': 'Euclid Av',
  'lat': 40.675377,
  'lon': -73.872106,
  'parent_id': 'A55'},
 {'stop_id': 'A57',
  'name': 'Grant Av',
  'lat': 40.677044,
  'lon': -73.86505,
  'parent_id': 'A57'},
 {'stop_id': 'A59',
  'name': '80 St',
  'lat': 40.679371,
  'lon': -73.858992,
  'parent_id': 'A59'},
 {'stop_id': 'A60',
  'name': '88 St',
  'lat': 40.679843,
  'lon': -73.85147,
  'parent_id': 'A60'},
 {'stop_id': 'A61',
  'name': 'Rockaway Blvd',
  'lat': 40.680429,
  'lon': -73.843853,
  'parent_id': 'A61'},
 {'stop_id': 'A63',
  'name': '104 St',
  'lat': 40.681711,
  'lon': -73.837683,
  'parent_id': 'A63'},
 {'stop_id': 'A64',
  'name': '111 St',
  'lat': 40.684331,
  'lon': -73.832163,
  'parent_id': 'A64'},
 {'stop_id': 'A65',
  'name': 'Ozone Park-Lefferts Blvd',
  'lat': 40.685951,
  'lon': -73.825798,
  'parent_id': 'A65'},
 {'stop_id': 'B04',
  'name': '21 St-Queensbridge',
  'lat': 40.754203,
  'lon': -73.942836,
  'parent_id': 'B04'},
 {'stop_id': 'B06',
  'name': 'Roosevelt Island',
  'lat': 40.759145,
  'lon': -73.95326,
  'parent_id': 'B06'},
 {'stop_id': 'B10',
  'name': '57 St',
  'lat': 40.763972,
  'lon': -73.97745,
  'parent_id': 'B10'},
 {'stop_id': 'B12',
  'name': '9 Av',
  'lat': 40.646292,
  'lon': -73.994324,
  'parent_id': 'B12'},
 {'stop_id': 'B13',
  'name': 'Fort Hamilton Pkwy',
  'lat': 40.640914,
  'lon': -73.994304,
  'parent_id': 'B13'},
 {'stop_id': 'B14',
  'name': '50 St',
  'lat': 40.63626,
  'lon': -73.994791,
  'parent_id': 'B14'},
 {'stop_id': 'B15',
  'name': '55 St',
  'lat': 40.631435,
  'lon': -73.995476,
  'parent_id': 'B15'},
 {'stop_id': 'B17',
  'name': '71 St',
  'lat': 40.619589,
  'lon': -73.998864,
  'parent_id': 'B17'},
 {'stop_id': 'B18',
  'name': '79 St',
  'lat': 40.613501,
  'lon': -74.00061,
  'parent_id': 'B18'},
 {'stop_id': 'B19',
  'name': '18 Av',
  'lat': 40.607954,
  'lon': -74.001736,
  'parent_id': 'B19'},
 {'stop_id': 'B20',
  'name': '20 Av',
  'lat': 40.604556,
  'lon': -73.998168,
  'parent_id': 'B20'},
 {'stop_id': 'B21',
  'name': 'Bay Pkwy',
  'lat': 40.601875,
  'lon': -73.993728,
  'parent_id': 'B21'},
 {'stop_id': 'B22',
  'name': '25 Av',
  'lat': 40.597704,
  'lon': -73.986829,
  'parent_id': 'B22'},
 {'stop_id': 'B23',
  'name': 'Bay 50 St',
  'lat': 40.588841,
  'lon': -73.983765,
  'parent_id': 'B23'},
 {'stop_id': 'D01',
  'name': 'Norwood-205 St',
  'lat': 40.874811,
  'lon': -73.878855,
  'parent_id': 'D01'},
 {'stop_id': 'D03',
  'name': 'Bedford Park Blvd',
  'lat': 40.873244,
  'lon': -73.887138,
  'parent_id': 'D03'},
 {'stop_id': 'D04',
  'name': 'Kingsbridge Rd',
  'lat': 40.866978,
  'lon': -73.893509,
  'parent_id': 'D04'},
 {'stop_id': 'D05',
  'name': 'Fordham Rd',
  'lat': 40.861296,
  'lon': -73.897749,
  'parent_id': 'D05'},
 {'stop_id': 'D06',
  'name': '182-183 Sts',
  'lat': 40.856093,
  'lon': -73.900741,
  'parent_id': 'D06'},
 {'stop_id': 'D07',
  'name': 'Tremont Av',
  'lat': 40.85041,
  'lon': -73.905227,
  'parent_id': 'D07'},
 {'stop_id': 'D08',
  'name': '174-175 Sts',
  'lat': 40.8459,
  'lon': -73.910136,
  'parent_id': 'D08'},
 {'stop_id': 'D09',
  'name': '170 St',
  'lat': 40.839306,
  'lon': -73.9134,
  'parent_id': 'D09'},
 {'stop_id': 'D10',
  'name': '167 St',
  'lat': 40.833771,
  'lon': -73.91844,
  'parent_id': 'D10'},
 {'stop_id': 'D12',
  'name': '155 St',
  'lat': 40.830135,
  'lon': -73.938209,
  'parent_id': 'D12'},
 {'stop_id': 'D14',
  'name': '7 Av',
  'lat': 40.762862,
  'lon': -73.981637,
  'parent_id': 'D14'},
 {'stop_id': 'D15',
  'name': '47-50 Sts-Rockefeller Ctr',
  'lat': 40.758663,
  'lon': -73.981329,
  'parent_id': 'D15'},
 {'stop_id': 'D18',
  'name': '23 St',
  'lat': 40.742878,
  'lon': -73.992821,
  'parent_id': 'D18'},
 {'stop_id': 'D22',
  'name': 'Grand St',
  'lat': 40.718267,
  'lon': -73.993753,
  'parent_id': 'D22'},
 {'stop_id': 'D25',
  'name': '7 Av',
  'lat': 40.67705,
  'lon': -73.972367,
  'parent_id': 'D25'},
 {'stop_id': 'D26',
  'name': 'Prospect Park',
  'lat': 40.661614,
  'lon': -73.962246,
  'parent_id': 'D26'},
 {'stop_id': 'D27',
  'name': 'Parkside Av',
  'lat': 40.655292,
  'lon': -73.961495,
  'parent_id': 'D27'},
 {'stop_id': 'D28',
  'name': 'Church Av',
  'lat': 40.650527,
  'lon': -73.962982,
  'parent_id': 'D28'},
 {'stop_id': 'D29',
  'name': 'Beverley Rd',
  'lat': 40.644031,
  'lon': -73.964492,
  'parent_id': 'D29'},
 {'stop_id': 'D30',
  'name': 'Cortelyou Rd',
  'lat': 40.640927,
  'lon': -73.963891,
  'parent_id': 'D30'},
 {'stop_id': 'D31',
  'name': 'Newkirk Plaza',
  'lat': 40.635082,
  'lon': -73.962793,
  'parent_id': 'D31'},
 {'stop_id': 'D32',
  'name': 'Avenue H',
  'lat': 40.62927,
  'lon': -73.961639,
  'parent_id': 'D32'},
 {'stop_id': 'D33',
  'name': 'Avenue J',
  'lat': 40.625039,
  'lon': -73.960803,
  'parent_id': 'D33'},
 {'stop_id': 'D34',
  'name': 'Avenue M',
  'lat': 40.617618,
  'lon': -73.959399,
  'parent_id': 'D34'},
 {'stop_id': 'D35',
  'name': 'Kings Hwy',
  'lat': 40.60867,
  'lon': -73.957734,
  'parent_id': 'D35'},
 {'stop_id': 'D37',
  'name': 'Avenue U',
  'lat': 40.5993,
  'lon': -73.955929,
  'parent_id': 'D37'},
 {'stop_id': 'D38',
  'name': 'Neck Rd',
  'lat': 40.595246,
  'lon': -73.955161,
  'parent_id': 'D38'},
 {'stop_id': 'D39',
  'name': 'Sheepshead Bay',
  'lat': 40.586896,
  'lon': -73.954155,
  'parent_id': 'D39'},
 {'stop_id': 'D40',
  'name': 'Brighton Beach',
  'lat': 40.577621,
  'lon': -73.961376,
  'parent_id': 'D40'},
 {'stop_id': 'D41',
  'name': 'Ocean Pkwy',
  'lat': 40.576312,
  'lon': -73.968501,
  'parent_id': 'D41'},
 {'stop_id': 'D42',
  'name': 'W 8 St-NY Aquarium',
  'lat': 40.576127,
  'lon': -73.975939,
  'parent_id': 'D42'},
 {'stop_id': 'D43',
  'name': 'Coney Island-Stillwell Av',
  'lat': 40.577422,
  'lon': -73.981233,
  'parent_id': 'D43'},
 {'stop_id': 'F01',
  'name': 'Jamaica-179 St',
  'lat': 40.712646,
  'lon': -73.783817,
  'parent_id': 'F01'},
 {'stop_id': 'F02',
  'name': '169 St',
  'lat': 40.71047,
  'lon': -73.793604,
  'parent_id': 'F02'},
 {'stop_id': 'F03',
  'name': 'Parsons Blvd',
  'lat': 40.707564,
  'lon': -73.803326,
  'parent_id': 'F03'},
 {'stop_id': 'F04',
  'name': 'Sutphin Blvd',
  'lat': 40.70546,
  'lon': -73.810708,
  'parent_id': 'F04'},
 {'stop_id': 'F05',
  'name': 'Briarwood',
  'lat': 40.709179,
  'lon': -73.820574,
  'parent_id': 'F05'},
 {'stop_id': 'F06',
  'name': 'Kew Gardens-Union Tpke',
  'lat': 40.714441,
  'lon': -73.831008,
  'parent_id': 'F06'},
 {'stop_id': 'F07',
  'name': '75 Av',
  'lat': 40.718331,
  'lon': -73.837324,
  'parent_id': 'F07'},
 {'stop_id': 'F12',
  'name': '5 Av/53 St',
  'lat': 40.760167,
  'lon': -73.975224,
  'parent_id': 'F12'},
 {'stop_id': 'F14',
  'name': '2 Av',
  'lat': 40.723402,
  'lon': -73.989938,
  'parent_id': 'F14'},
 {'stop_id': 'F16',
  'name': 'East Broadway',
  'lat': 40.713715,
  'lon': -73.990173,
  'parent_id': 'F16'},
 {'stop_id': 'F18',
  'name': 'York St',
  'lat': 40.701397,
  'lon': -73.986751,
  'parent_id': 'F18'},
 {'stop_id': 'F20',
  'name': 'Bergen St',
  'lat': 40.686145,
  'lon': -73.990862,
  'parent_id': 'F20'},
 {'stop_id': 'F21',
  'name': 'Carroll St',
  'lat': 40.680303,
  'lon': -73.995048,
  'parent_id': 'F21'},
 {'stop_id': 'F22',
  'name': 'Smith-9 Sts',
  'lat': 40.67358,
  'lon': -73.995959,
  'parent_id': 'F22'},
 {'stop_id': 'F24',
  'name': '7 Av',
  'lat': 40.666271,
  'lon': -73.980305,
  'parent_id': 'F24'},
 {'stop_id': 'F25',
  'name': '15 St-Prospect Park',
  'lat': 40.660365,
  'lon': -73.979493,
  'parent_id': 'F25'},
 {'stop_id': 'F26',
  'name': 'Fort Hamilton Pkwy',
  'lat': 40.650782,
  'lon': -73.975776,
  'parent_id': 'F26'},
 {'stop_id': 'F27',
  'name': 'Church Av',
  'lat': 40.644041,
  'lon': -73.979678,
  'parent_id': 'F27'},
 {'stop_id': 'F29',
  'name': 'Ditmas Av',
  'lat': 40.636119,
  'lon': -73.978172,
  'parent_id': 'F29'},
 {'stop_id': 'F30',
  'name': '18 Av',
  'lat': 40.629755,
  'lon': -73.976971,
  'parent_id': 'F30'},
 {'stop_id': 'F31',
  'name': 'Avenue I',
  'lat': 40.625322,
  'lon': -73.976127,
  'parent_id': 'F31'},
 {'stop_id': 'F32',
  'name': 'Bay Pkwy',
  'lat': 40.620769,
  'lon': -73.975264,
  'parent_id': 'F32'},
 {'stop_id': 'F33',
  'name': 'Avenue N',
  'lat': 40.61514,
  'lon': -73.974197,
  'parent_id': 'F33'},
 {'stop_id': 'F34',
  'name': 'Avenue P',
  'lat': 40.608944,
  'lon': -73.973022,
  'parent_id': 'F34'},
 {'stop_id': 'F35',
  'name': 'Kings Hwy',
  'lat': 40.603217,
  'lon': -73.972361,
  'parent_id': 'F35'},
 {'stop_id': 'F36',
  'name': 'Avenue U',
  'lat': 40.596063,
  'lon': -73.973357,
  'parent_id': 'F36'},
 {'stop_id': 'F38',
  'name': 'Avenue X',
  'lat': 40.58962,
  'lon': -73.97425,
  'parent_id': 'F38'},
 {'stop_id': 'F39',
  'name': 'Neptune Av',
  'lat': 40.581011,
  'lon': -73.974574,
  'parent_id': 'F39'},
 {'stop_id': 'G05',
  'name': 'Jamaica Center-Parsons/Archer',
  'lat': 40.702147,
  'lon': -73.801109,
  'parent_id': 'G05'},
 {'stop_id': 'G06',
  'name': 'Sutphin Blvd-Archer Av-JFK Airport',
  'lat': 40.700486,
  'lon': -73.807969,
  'parent_id': 'G06'},
 {'stop_id': 'G07',
  'name': 'Jamaica-Van Wyck',
  'lat': 40.702566,
  'lon': -73.816859,
  'parent_id': 'G07'},
 {'stop_id': 'G08',
  'name': 'Forest Hills-71 Av',
  'lat': 40.721691,
  'lon': -73.844521,
  'parent_id': 'G08'},
 {'stop_id': 'G09',
  'name': '67 Av',
  'lat': 40.726523,
  'lon': -73.852719,
  'parent_id': 'G09'},
 {'stop_id': 'G10',
  'name': '63 Dr-Rego Park',
  'lat': 40.729846,
  'lon': -73.861604,
  'parent_id': 'G10'},
 {'stop_id': 'G11',
  'name': 'Woodhaven Blvd',
  'lat': 40.733106,
  'lon': -73.869229,
  'parent_id': 'G11'},
 {'stop_id': 'G12',
  'name': 'Grand Av-Newtown',
  'lat': 40.737015,
  'lon': -73.877223,
  'parent_id': 'G12'},
 {'stop_id': 'G13',
  'name': 'Elmhurst Av',
  'lat': 40.742454,
  'lon': -73.882017,
  'parent_id': 'G13'},
 {'stop_id': 'G15',
  'name': '65 St',
  'lat': 40.749669,
  'lon': -73.898453,
  'parent_id': 'G15'},
 {'stop_id': 'G16',
  'name': 'Northern Blvd',
  'lat': 40.752885,
  'lon': -73.906006,
  'parent_id': 'G16'},
 {'stop_id': 'G18',
  'name': '46 St',
  'lat': 40.756312,
  'lon': -73.913333,
  'parent_id': 'G18'},
 {'stop_id': 'G19',
  'name': 'Steinway St',
  'lat': 40.756879,
  'lon': -73.92074,
  'parent_id': 'G19'},
 {'stop_id': 'G20',
  'name': '36 St',
  'lat': 40.752039,
  'lon': -73.928781,
  'parent_id': 'G20'},
 {'stop_id': 'G21',
  'name': 'Queens Plaza',
  'lat': 40.748973,
  'lon': -73.937243,
  'parent_id': 'G21'},
 {'stop_id': 'G24',
  'name': '21 St',
  'lat': 40.744065,
  'lon': -73.949724,
  'parent_id': 'G24'},
 {'stop_id': 'G26',
  'name': 'Greenpoint Av',
  'lat': 40.731352,
  'lon': -73.954449,
  'parent_id': 'G26'},
 {'stop_id': 'G28',
  'name': 'Nassau Av',
  'lat': 40.724635,
  'lon': -73.951277,
  'parent_id': 'G28'},
 {'stop_id': 'G30',
  'name': 'Broadway',
  'lat': 40.706092,
  'lon': -73.950308,
  'parent_id': 'G30'},
 {'stop_id': 'G31',
  'name': 'Flushing Av',
  'lat': 40.700377,
  'lon': -73.950234,
  'parent_id': 'G31'},
 {'stop_id': 'G32',
  'name': 'Myrtle-Willoughby Avs',
  'lat': 40.694568,
  'lon': -73.949046,
  'parent_id': 'G32'},
 {'stop_id': 'G33',
  'name': 'Bedford-Nostrand Avs',
  'lat': 40.689627,
  'lon': -73.953522,
  'parent_id': 'G33'},
 {'stop_id': 'G34',
  'name': 'Classon Av',
  'lat': 40.688873,
  'lon': -73.96007,
  'parent_id': 'G34'},
 {'stop_id': 'G35',
  'name': 'Clinton-Washington Avs',
  'lat': 40.688089,
  'lon': -73.966839,
  'parent_id': 'G35'},
 {'stop_id': 'G36',
  'name': 'Fulton St',
  'lat': 40.687119,
  'lon': -73.975375,
  'parent_id': 'G36'},
 {'stop_id': 'H01',
  'name': 'Aqueduct Racetrack',
  'lat': 40.668234,
  'lon': -73.834058,
  'parent_id': 'H01'},
 {'stop_id': 'H02',
  'name': 'Aqueduct-N Conduit Av',
  'lat': 40.668234,
  'lon': -73.834058,
  'parent_id': 'H02'},
 {'stop_id': 'H03',
  'name': 'Howard Beach-JFK Airport',
  'lat': 40.660476,
  'lon': -73.830301,
  'parent_id': 'H03'},
 {'stop_id': 'H04',
  'name': 'Broad Channel',
  'lat': 40.608382,
  'lon': -73.815925,
  'parent_id': 'H04'},
 {'stop_id': 'H06',
  'name': 'Beach 67 St',
  'lat': 40.590927,
  'lon': -73.796924,
  'parent_id': 'H06'},
 {'stop_id': 'H07',
  'name': 'Beach 60 St',
  'lat': 40.592374,
  'lon': -73.788522,
  'parent_id': 'H07'},
 {'stop_id': 'H08',
  'name': 'Beach 44 St',
  'lat': 40.592943,
  'lon': -73.776013,
  'parent_id': 'H08'},
 {'stop_id': 'H09',
  'name': 'Beach 36 St',
  'lat': 40.595398,
  'lon': -73.768175,
  'parent_id': 'H09'},
 {'stop_id': 'H10',
  'name': 'Beach 25 St',
  'lat': 40.600066,
  'lon': -73.761353,
  'parent_id': 'H10'},
 {'stop_id': 'H11',
  'name': 'Far Rockaway-Mott Av',
  'lat': 40.603995,
  'lon': -73.755405,
  'parent_id': 'H11'},
 {'stop_id': 'H12',
  'name': 'Beach 90 St',
  'lat': 40.588034,
  'lon': -73.813641,
  'parent_id': 'H12'},
 {'stop_id': 'H13',
  'name': 'Beach 98 St',
  'lat': 40.585307,
  'lon': -73.820558,
  'parent_id': 'H13'},
 {'stop_id': 'H14',
  'name': 'Beach 105 St',
  'lat': 40.583209,
  'lon': -73.827559,
  'parent_id': 'H14'},
 {'stop_id': 'H15',
  'name': 'Rockaway Park-Beach 116 St',
  'lat': 40.580903,
  'lon': -73.835592,
  'parent_id': 'H15'},
 {'stop_id': 'H19',
  'name': 'Broad Channel',
  'lat': 40.609014,
  'lon': -73.816024,
  'parent_id': 'H19'},
 {'stop_id': 'J12',
  'name': '121 St',
  'lat': 40.700492,
  'lon': -73.828294,
  'parent_id': 'J12'},
 {'stop_id': 'J13',
  'name': '111 St',
  'lat': 40.697418,
  'lon': -73.836345,
  'parent_id': 'J13'},
 {'stop_id': 'J14',
  'name': '104 St',
  'lat': 40.695178,
  'lon': -73.84433,
  'parent_id': 'J14'},
 {'stop_id': 'J15',
  'name': 'Woodhaven Blvd',
  'lat': 40.693879,
  'lon': -73.851576,
  'parent_id': 'J15'},
 {'stop_id': 'J16',
  'name': '85 St-Forest Pkwy',
  'lat': 40.692435,
  'lon': -73.86001,
  'parent_id': 'J16'},
 {'stop_id': 'J17',
  'name': '75 St-Elderts Ln',
  'lat': 40.691324,
  'lon': -73.867139,
  'parent_id': 'J17'},
 {'stop_id': 'J19',
  'name': 'Cypress Hills',
  'lat': 40.689941,
  'lon': -73.87255,
  'parent_id': 'J19'},
 {'stop_id': 'J20',
  'name': 'Crescent St',
  'lat': 40.683194,
  'lon': -73.873785,
  'parent_id': 'J20'},
 {'stop_id': 'J21',
  'name': 'Norwood Av',
  'lat': 40.68141,
  'lon': -73.880039,
  'parent_id': 'J21'},
 {'stop_id': 'J22',
  'name': 'Cleveland St',
  'lat': 40.679947,
  'lon': -73.884639,
  'parent_id': 'J22'},
 {'stop_id': 'J23',
  'name': 'Van Siclen Av',
  'lat': 40.678024,
  'lon': -73.891688,
  'parent_id': 'J23'},
 {'stop_id': 'J24',
  'name': 'Alabama Av',
  'lat': 40.676992,
  'lon': -73.898654,
  'parent_id': 'J24'},
 {'stop_id': 'J28',
  'name': 'Chauncey St',
  'lat': 40.682893,
  'lon': -73.910456,
  'parent_id': 'J28'},
 {'stop_id': 'J29',
  'name': 'Halsey St',
  'lat': 40.68637,
  'lon': -73.916559,
  'parent_id': 'J29'},
 {'stop_id': 'J30',
  'name': 'Gates Av',
  'lat': 40.68963,
  'lon': -73.92227,
  'parent_id': 'J30'},
 {'stop_id': 'J31',
  'name': 'Kosciuszko St',
  'lat': 40.693342,
  'lon': -73.928814,
  'parent_id': 'J31'},
 {'stop_id': 'L05',
  'name': '3 Av',
  'lat': 40.732849,
  'lon': -73.986122,
  'parent_id': 'L05'},
 {'stop_id': 'L06',
  'name': '1 Av',
  'lat': 40.730953,
  'lon': -73.981628,
  'parent_id': 'L06'},
 {'stop_id': 'L08',
  'name': 'Bedford Av',
  'lat': 40.717304,
  'lon': -73.956872,
  'parent_id': 'L08'},
 {'stop_id': 'L11',
  'name': 'Graham Av',
  'lat': 40.714565,
  'lon': -73.944053,
  'parent_id': 'L11'},
 {'stop_id': 'L12',
  'name': 'Grand St',
  'lat': 40.711926,
  'lon': -73.94067,
  'parent_id': 'L12'},
 {'stop_id': 'L13',
  'name': 'Montrose Av',
  'lat': 40.707739,
  'lon': -73.93985,
  'parent_id': 'L13'},
 {'stop_id': 'L14',
  'name': 'Morgan Av',
  'lat': 40.706152,
  'lon': -73.933147,
  'parent_id': 'L14'},
 {'stop_id': 'L15',
  'name': 'Jefferson St',
  'lat': 40.706607,
  'lon': -73.922913,
  'parent_id': 'L15'},
 {'stop_id': 'L16',
  'name': 'DeKalb Av',
  'lat': 40.703811,
  'lon': -73.918425,
  'parent_id': 'L16'},
 {'stop_id': 'L19',
  'name': 'Halsey St',
  'lat': 40.695602,
  'lon': -73.904084,
  'parent_id': 'L19'},
 {'stop_id': 'L20',
  'name': 'Wilson Av',
  'lat': 40.688764,
  'lon': -73.904046,
  'parent_id': 'L20'},
 {'stop_id': 'L21',
  'name': 'Bushwick Av-Aberdeen St',
  'lat': 40.682829,
  'lon': -73.905249,
  'parent_id': 'L21'},
 {'stop_id': 'L24',
  'name': 'Atlantic Av',
  'lat': 40.675345,
  'lon': -73.903097,
  'parent_id': 'L24'},
 {'stop_id': 'L25',
  'name': 'Sutter Av',
  'lat': 40.669367,
  'lon': -73.901975,
  'parent_id': 'L25'},
 {'stop_id': 'L27',
  'name': 'New Lots Av',
  'lat': 40.658733,
  'lon': -73.899232,
  'parent_id': 'L27'},
 {'stop_id': 'L28',
  'name': 'East 105 St',
  'lat': 40.650573,
  'lon': -73.899485,
  'parent_id': 'L28'},
 {'stop_id': 'L29',
  'name': 'Canarsie-Rockaway Pkwy',
  'lat': 40.646654,
  'lon': -73.90185,
  'parent_id': 'L29'},
 {'stop_id': 'M01',
  'name': 'Middle Village-Metropolitan Av',
  'lat': 40.711396,
  'lon': -73.889601,
  'parent_id': 'M01'},
 {'stop_id': 'M04',
  'name': 'Fresh Pond Rd',
  'lat': 40.706186,
  'lon': -73.895877,
  'parent_id': 'M04'},
 {'stop_id': 'M05',
  'name': 'Forest Av',
  'lat': 40.704423,
  'lon': -73.903077,
  'parent_id': 'M05'},
 {'stop_id': 'M06',
  'name': 'Seneca Av',
  'lat': 40.702762,
  'lon': -73.90774,
  'parent_id': 'M06'},
 {'stop_id': 'M09',
  'name': 'Knickerbocker Av',
  'lat': 40.698664,
  'lon': -73.919711,
  'parent_id': 'M09'},
 {'stop_id': 'M10',
  'name': 'Central Av',
  'lat': 40.697857,
  'lon': -73.927397,
  'parent_id': 'M10'},
 {'stop_id': 'M11',
  'name': 'Myrtle Av',
  'lat': 40.697207,
  'lon': -73.935657,
  'parent_id': 'M11'},
 {'stop_id': 'M12',
  'name': 'Flushing Av',
  'lat': 40.70026,
  'lon': -73.941126,
  'parent_id': 'M12'},
 {'stop_id': 'M13',
  'name': 'Lorimer St',
  'lat': 40.703869,
  'lon': -73.947408,
  'parent_id': 'M13'},
 {'stop_id': 'M14',
  'name': 'Hewes St',
  'lat': 40.70687,
  'lon': -73.953431,
  'parent_id': 'M14'},
 {'stop_id': 'M16',
  'name': 'Marcy Av',
  'lat': 40.708359,
  'lon': -73.957757,
  'parent_id': 'M16'},
 {'stop_id': 'M19',
  'name': 'Bowery',
  'lat': 40.72028,
  'lon': -73.993915,
  'parent_id': 'M19'},
 {'stop_id': 'M23',
  'name': 'Broad St',
  'lat': 40.706476,
  'lon': -74.011056,
  'parent_id': 'M23'},
 {'stop_id': 'N02',
  'name': '8 Av',
  'lat': 40.635064,
  'lon': -74.011719,
  'parent_id': 'N02'},
 {'stop_id': 'N03',
  'name': 'Fort Hamilton Pkwy',
  'lat': 40.631386,
  'lon': -74.005351,
  'parent_id': 'N03'},
 {'stop_id': 'N05',
  'name': '18 Av',
  'lat': 40.620671,
  'lon': -73.990414,
  'parent_id': 'N05'},
 {'stop_id': 'N06',
  'name': '20 Av',
  'lat': 40.61741,
  'lon': -73.985026,
  'parent_id': 'N06'},
 {'stop_id': 'N07',
  'name': 'Bay Pkwy',
  'lat': 40.611815,
  'lon': -73.981848,
  'parent_id': 'N07'},
 {'stop_id': 'N08',
  'name': 'Kings Hwy',
  'lat': 40.603923,
  'lon': -73.980353,
  'parent_id': 'N08'},
 {'stop_id': 'N09',
  'name': 'Avenue U',
  'lat': 40.597473,
  'lon': -73.979137,
  'parent_id': 'N09'},
 {'stop_id': 'N10',
  'name': '86 St',
  'lat': 40.592721,
  'lon': -73.97823,
  'parent_id': 'N10'},
 {'stop_id': 'N12',
  'name': 'S.B. Coney Island',
  'lat': 40.577422,
  'lon': -73.981233,
  'parent_id': 'N12'},
 {'stop_id': 'Q03',
  'name': '72 St',
  'lat': 40.768799,
  'lon': -73.958424,
  'parent_id': 'Q03'},
 {'stop_id': 'Q04',
  'name': '86 St',
  'lat': 40.777891,
  'lon': -73.951787,
  'parent_id': 'Q04'},
 {'stop_id': 'Q05',
  'name': '96 St',
  'lat': 40.784318,
  'lon': -73.947152,
  'parent_id': 'Q05'},
 {'stop_id': 'R01',
  'name': 'Astoria-Ditmars Blvd',
  'lat': 40.775036,
  'lon': -73.912034,
  'parent_id': 'R01'},
 {'stop_id': 'R03',
  'name': 'Astoria Blvd',
  'lat': 40.770258,
  'lon': -73.917843,
  'parent_id': 'R03'},
 {'stop_id': 'R04',
  'name': '30 Av',
  'lat': 40.766779,
  'lon': -73.921479,
  'parent_id': 'R04'},
 {'stop_id': 'R05',
  'name': 'Broadway',
  'lat': 40.76182,
  'lon': -73.925508,
  'parent_id': 'R05'},
 {'stop_id': 'R06',
  'name': '36 Av',
  'lat': 40.756804,
  'lon': -73.929575,
  'parent_id': 'R06'},
 {'stop_id': 'R08',
  'name': '39 Av-Dutch Kills',
  'lat': 40.752882,
  'lon': -73.932755,
  'parent_id': 'R08'},
 {'stop_id': 'R13',
  'name': '5 Av/59 St',
  'lat': 40.764811,
  'lon': -73.973347,
  'parent_id': 'R13'},
 {'stop_id': 'R14',
  'name': '57 St-7 Av',
  'lat': 40.764664,
  'lon': -73.980658,
  'parent_id': 'R14'},
 {'stop_id': 'R15',
  'name': '49 St',
  'lat': 40.759901,
  'lon': -73.984139,
  'parent_id': 'R15'},
 {'stop_id': 'R18',
  'name': '28 St',
  'lat': 40.745494,
  'lon': -73.988691,
  'parent_id': 'R18'},
 {'stop_id': 'R19',
  'name': '23 St',
  'lat': 40.741303,
  'lon': -73.989344,
  'parent_id': 'R19'},
 {'stop_id': 'R21',
  'name': '8 St-NYU',
  'lat': 40.730328,
  'lon': -73.992629,
  'parent_id': 'R21'},
 {'stop_id': 'R22',
  'name': 'Prince St',
  'lat': 40.724329,
  'lon': -73.997702,
  'parent_id': 'R22'},
 {'stop_id': 'R24',
  'name': 'City Hall',
  'lat': 40.713282,
  'lon': -74.006978,
  'parent_id': 'R24'},
 {'stop_id': 'R26',
  'name': 'Rector St',
  'lat': 40.70722,
  'lon': -74.013342,
  'parent_id': 'R26'},
 {'stop_id': 'R30',
  'name': 'DeKalb Av',
  'lat': 40.690635,
  'lon': -73.981824,
  'parent_id': 'R30'},
 {'stop_id': 'R32',
  'name': 'Union St',
  'lat': 40.677316,
  'lon': -73.98311,
  'parent_id': 'R32'},
 {'stop_id': 'R34',
  'name': 'Prospect Av',
  'lat': 40.665414,
  'lon': -73.992872,
  'parent_id': 'R34'},
 {'stop_id': 'R35',
  'name': '25 St',
  'lat': 40.660397,
  'lon': -73.998091,
  'parent_id': 'R35'},
 {'stop_id': 'R36',
  'name': '36 St',
  'lat': 40.655144,
  'lon': -74.003549,
  'parent_id': 'R36'},
 {'stop_id': 'R39',
  'name': '45 St',
  'lat': 40.648939,
  'lon': -74.010006,
  'parent_id': 'R39'},
 {'stop_id': 'R40',
  'name': '53 St',
  'lat': 40.645069,
  'lon': -74.014034,
  'parent_id': 'R40'},
 {'stop_id': 'R41',
  'name': '59 St',
  'lat': 40.641362,
  'lon': -74.017881,
  'parent_id': 'R41'},
 {'stop_id': 'R42',
  'name': 'Bay Ridge Av',
  'lat': 40.634967,
  'lon': -74.023377,
  'parent_id': 'R42'},
 {'stop_id': 'R43',
  'name': '77 St',
  'lat': 40.629742,
  'lon': -74.02551,
  'parent_id': 'R43'},
 {'stop_id': 'R44',
  'name': '86 St',
  'lat': 40.622687,
  'lon': -74.028398,
  'parent_id': 'R44'},
 {'stop_id': 'R45',
  'name': 'Bay Ridge-95 St',
  'lat': 40.616622,
  'lon': -74.030876,
  'parent_id': 'R45'},
 {'stop_id': 'S03',
  'name': 'Park Pl',
  'lat': 40.674772,
  'lon': -73.957624,
  'parent_id': 'S03'},
 {'stop_id': 'S09',
  'name': 'Tottenville',
  'lat': 40.512764,
  'lon': -74.251961,
  'parent_id': 'S09'},
 {'stop_id': 'S11',
  'name': 'Arthur Kill',
  'lat': 40.516578,
  'lon': -74.242096,
  'parent_id': 'S11'},
 {'stop_id': 'S13',
  'name': 'Richmond Valley',
  'lat': 40.519631,
  'lon': -74.229141,
  'parent_id': 'S13'},
 {'stop_id': 'S14',
  'name': 'Pleasant Plains',
  'lat': 40.52241,
  'lon': -74.217847,
  'parent_id': 'S14'},
 {'stop_id': 'S15',
  'name': "Prince's Bay",
  'lat': 40.525507,
  'lon': -74.200064,
  'parent_id': 'S15'},
 {'stop_id': 'S16',
  'name': 'Huguenot',
  'lat': 40.533674,
  'lon': -74.191794,
  'parent_id': 'S16'},
 {'stop_id': 'S17',
  'name': 'Annadale',
  'lat': 40.54046,
  'lon': -74.178217,
  'parent_id': 'S17'},
 {'stop_id': 'S18',
  'name': 'Eltingville',
  'lat': 40.544601,
  'lon': -74.16457,
  'parent_id': 'S18'},
 {'stop_id': 'S19',
  'name': 'Great Kills',
  'lat': 40.551231,
  'lon': -74.151399,
  'parent_id': 'S19'},
 {'stop_id': 'S20',
  'name': 'Bay Terrace',
  'lat': 40.5564,
  'lon': -74.136907,
  'parent_id': 'S20'},
 {'stop_id': 'S21',
  'name': 'Oakwood Heights',
  'lat': 40.56511,
  'lon': -74.12632,
  'parent_id': 'S21'},
 {'stop_id': 'S22',
  'name': 'New Dorp',
  'lat': 40.57348,
  'lon': -74.11721,
  'parent_id': 'S22'},
 {'stop_id': 'S23',
  'name': 'Grant City',
  'lat': 40.578965,
  'lon': -74.109704,
  'parent_id': 'S23'},
 {'stop_id': 'S24',
  'name': 'Jefferson Av',
  'lat': 40.583591,
  'lon': -74.103338,
  'parent_id': 'S24'},
 {'stop_id': 'S25',
  'name': 'Dongan Hills',
  'lat': 40.588849,
  'lon': -74.09609,
  'parent_id': 'S25'},
 {'stop_id': 'S26',
  'name': 'Old Town',
  'lat': 40.596612,
  'lon': -74.087368,
  'parent_id': 'S26'},
 {'stop_id': 'S27',
  'name': 'Grasmere',
  'lat': 40.603117,
  'lon': -74.084087,
  'parent_id': 'S27'},
 {'stop_id': 'S28',
  'name': 'Clifton',
  'lat': 40.621319,
  'lon': -74.071402,
  'parent_id': 'S28'},
 {'stop_id': 'S29',
  'name': 'Stapleton',
  'lat': 40.627915,
  'lon': -74.075162,
  'parent_id': 'S29'},
 {'stop_id': 'S30',
  'name': 'Tompkinsville',
  'lat': 40.636949,
  'lon': -74.074835,
  'parent_id': 'S30'},
 {'stop_id': 'S31',
  'name': 'St George',
  'lat': 40.643748,
  'lon': -74.073643,
  'parent_id': 'S31'}]

# %%
import json
with open("stations.json", "w") as outfile: 
    json.dump(stations, outfile)

# %%
dataTest = json.load(open('stations.json'))

# %%
def getStopID(name, direction, stations):
    for station in stations:
        if station['name'] == name:
            if direction == 'uptown':
                return str(station['stop_id']) + 'N'
            elif direction == 'downtown':
                return str(station['stop_id']) + 'S'
            else:
                raise Exception('direction gotta be uptown or downtown')
    raise Exception('name not found')

# %%
def getTimes(feed, APIKey):
    routeId = ""
    
    # Request parameters
    headers = {'x-api-key': APIKey}
    
    # Get the train data from the MTA
    response = requests.get(feed, headers=headers, timeout=30)

    # Parse the protocol buffer that is returned
    feed = gtfs_realtime_pb2.FeedMessage()
    feed.ParseFromString(response.content)

    # Get a list of all the train data
    subway_feed = MessageToDict(feed)
    realtime_data = subway_feed['entity'] # train_data is a list

    # A list of all the arrivals we found for our station in the given feed
    arrivals = []
    # Iterate over each train arrival
    try:
        for train in realtime_data:
            # If there is a trip update with a stop time update
            if train.get('tripUpdate'):
                routeId = train['tripUpdate']['trip']['routeId']
                if (train['tripUpdate'].get('stopTimeUpdate')):
                    # get for each stop time update that is at our stop
                    for update in train['tripUpdate'].get('stopTimeUpdate'):

                        # checking for the arrival/departure keys; these keys are missing at the last stops of the line
                        if update.get('arrival'):
                            trainTime = update['arrival']['time']
                        elif update.get('departure'): 
                            trainTime = update['departure']['time']
                        else:
                            continue
                        
                        # Get the number of seconds from now to the arrival time
                        timeDelta = int(trainTime)-time.mktime(datetime.now().timetuple())

                        # If we alredy missed it, skip it
                        if (timeDelta < 0):
                            continue
                                            
                        # Calculate minutes and seconds until arrival
                        timeDeltaMin = int(timeDelta / 60)

                        timeDeltaSec = int(timeDelta % 60)

                        # Round to nearest minute
                        if (timeDeltaSec > 30):
                            timeDeltaMin = timeDeltaMin + 1

                        # Skips zeros
                        if (timeDeltaMin == 0):
                            continue
                        
                        # departureUnix = int(update['departure']['time'])
                        arrivalUnix = int(trainTime)

                        update['arrivalTime'] = datetime.fromtimestamp(arrivalUnix).strftime("%H:%M:%S")
                        # update['departure'] = datetime.fromtimestamp(departureUnix).strftime("%H:%M:%S")
                        update['minArrival'] = timeDeltaMin
                        update['routeId'] = routeId
                                
                        arrivals.append(update)
    except:
        raise Exception('mta api fetch error')
    return arrivals

# %%
feeds = [NQRWfeed,BDFMfeed,S123456feed,ACEHfeed,Lfeed,Gfeed,JZfeed,SIRfeed]
def getAllArrivals(feeds, APIKey):
    arrivals = []
    for feed in feeds:
        arrivals.extend(getTimes(feed, APIKey))
    return arrivals

# %%
'Christopher St-Sheridan Sq'

arrivals = getAllArrivals(feeds, APIKey)

def getArrivalStr(stopName, direction, getNextNum = 3, stations=stations, arrivals = arrivals):
    arrivalsSort = arrivals.copy()
    selStop = getStopID(name=stopName, direction=direction, stations=stations)
    arrivalsStop = [stop['minArrival'] for stop in arrivalsSort if stop['stopId'] == selStop]
    displayStr = ''
    selArrivals = arrivalsStop[0:getNextNum].copy()
    for arrivalInd, arrival in enumerate(selArrivals):
        if arrivalInd < len(selArrivals) -1:
            displayStr = displayStr + str(arrival) + ' min, '
        else:
            displayStr = displayStr + str(arrival) + ' min'
    return displayStr

# %%
getArrivalStr('Christopher St-Sheridan Sq', 'uptown')
# Out:
# '6 min, 13 min, 21 min, 29 min'

# %% [markdown]
# # testing module

# %%
import fetchTimes

# %%
fetchObj = fetchTimes.subwayFetch()

# %%
arrivals = fetchObj.getAllArrivals()
getArrivalStr= fetchObj.getArrivalStr(stopName='Christopher St-Sheridan Sq',direction='uptown',arrivals=arrivals)

# %%
getArrivalStr
# Out:
# '7 min, 15 min, 23 min'

# %%
fetchObj.getArrivalStr(stopName='Christopher St-Sheridan Sq',direction='downtown',arrivals=arrivals)
# Out:
# '2 min, 9 min, 14 min'
